# %% [markdown]
# <a href="https://colab.research.google.com/github/ObaidAshraf/GenAI_AgenticAI/blob/master/langchain_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install langchain dependencies

# %%
# !pip install -U -q langchain langchain-google-genai

# %% [markdown]
# ## Import Key

# %%
from google.colab import userdata
import os
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

# %%
import langchain_google_genai as genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
client = ChatGoogleGenerativeAI(
    model = "gemini-2.5-flash-lite",
)

# %%
response = client.invoke("What is the PKR to USD rate today?")

# %%
print(response.content)
# Out:
# I cannot provide real-time exchange rates. Exchange rates fluctuate constantly.
#
# To get the most up-to-date PKR to USD rate, I recommend checking one of the following reliable sources:
#
# *   **Reputable Financial News Websites:**
#     *   Bloomberg
#     *   Reuters
#     *   Google Finance (search for "PKR to USD")
#     *   XE.com
#
# *   **Currency Converter Apps:** Many smartphone apps offer real-time currency conversions.
#
# When you visit these sites, simply search for "PKR to USD" or "Pakistani Rupee to US Dollar" and you'll get the current exchange rate.
